# %%
import matplotlib
print(matplotlib.__version__)
print(matplotlib.get_backend())
matplotlib.use('nbagg')               # Has to appear before import matplotlib.pyplot
print(matplotlib.get_backend())
# Out:
# 3.2.2
# module://ipykernel.pylab.backend_inline
# nbAgg

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(facecolor=(1, 0, 0, .1))
plt.show()                                    # Needed for interactive plot to show up
# Out:
# <div id='507cb5ae-edea-4315-b5c9-d7c536486eff'></div>

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
fig = plt.figure()           # Initiate figure
a1 = fig.add_subplot(221)    # Adding axes. Argument means figure with 2 rows, two columns; select subplot 1

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

a1.scatter(X,Y)
a1.axhline(y=1,color='red')         # Add horizontal line. 
                                    # Colors from https://matplotlib.org/examples/color/named_colors.html

x =  np.linspace(-2*np.pi, 2*np.pi, 1000)

a2 = fig.add_subplot(224)    # Figure has 2 rows, 2 columns; select subplot 4
a2.plot(x,np.sin(x))
a2.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Some ways to loop through axes
fig, axes = plt.subplots(1,7,figsize=(18,4),sharex=True)
fig.subplots_adjust(wspace=0.5,hspace=0.5)

# for i in range(7):
#      _ = sns.boxplot(data=dtrain,x="type",y=dtrain.columns[i], ax=axes[i])


# For an array of plots, fig.axes contains a list

fig, axes = plt.subplots(3,3,figsize=(9,9))
fig.subplots_adjust(wspace=0.5,hspace=0.5)

for i, axes in enumerate(fig.axes):
    if (i <= 6):
        _ = sns.boxplot(data=dtrain,x="type",y=dtrain.columns[i], ax=axes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4e10ce23032d> in <module>
#      14 for i, axes in enumerate(fig.axes):
#      15     if (i <= 6):
# ---> 16         _ = sns.boxplot(data=dtrain,x="type",y=dtrain.columns[i], ax=axes)
#      17
#
# NameError: name 'sns' is not defined
